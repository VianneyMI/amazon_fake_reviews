# %%
import pandas as pd

# %% [markdown]
# Starting with subsets of the data

# %%
beauty_dataset=pd.read_json('data/ref/All_Beauty_5.json', lines=True)
beauty_dataset.head(5)
# Out:
#    overall  verified   reviewTime      reviewerID        asin  \
# 0        5      True   09 1, 2016  A3CIUOJXQ5VDQ2  B0000530HU
# 1        5      True  11 14, 2013  A3H7T87S984REU  B0000530HU
# 2        1      True  08 18, 2013  A3J034YH7UG4KT  B0000530HU
# 3        5     False   05 3, 2011  A2UEO5XR3598GI  B0000530HU
# 4        5      True   05 6, 2011  A3SFRT223XXWF7  B00006L9LC
#
#                                                style     reviewerName  \
# 0  {'Size:': ' 7.0 oz', 'Flavor:': ' Classic Ice ...         Shelly F
# 1  {'Size:': ' 7.0 oz', 'Flavor:': ' Classic Ice ...     houserules18
# 2  {'Size:': ' 7.0 oz', 'Flavor:': ' Classic Ice ...             Adam
# 3  {'Size:': ' 7.0 oz', 'Flavor:': ' Classic Ice ...           Rich K
# 4                          {'Size:': ' 200ml/6.7oz'}  C. C. Christian
#
#                                           reviewText  \
# 0                   As advertised. Reasonably priced
# 1  Like the oder and the feel when I put it on my...
# ...

# %%
beauty_dataset['style']
# Out:
# 0       {'Size:': ' 7.0 oz', 'Flavor:': ' Classic Ice ...
# 1       {'Size:': ' 7.0 oz', 'Flavor:': ' Classic Ice ...
# 2       {'Size:': ' 7.0 oz', 'Flavor:': ' Classic Ice ...
# 3       {'Size:': ' 7.0 oz', 'Flavor:': ' Classic Ice ...
# 4                               {'Size:': ' 200ml/6.7oz'}
#                               ...
# 5264                       {'Design:': ' ETA-C6B5F7C374'}
# 5265                       {'Design:': ' ETA-7117EE3788'}
# 5266                       {'Design:': ' ETA-BF66BD2F87'}
# 5267                       {'Design:': ' ETA-03868FCB34'}
# 5268                       {'Design:': ' ETA-C4893097E9'}
# Name: style, Length: 5269, dtype: object

# %%
beauty_dataset.drop(['style','image'], axis=1).describe(include='all') #style and image are causing issues with describe()
# Out:
#             overall verified   reviewTime     reviewerID        asin  \
# count   5269.000000     5269         5269           5269        5269
# unique          NaN        2          883            991          85
# top             NaN     True  07 14, 2016  AKJHHD5VEH7VG  B0012Y0ZG2
# freq            NaN     4280           33             12        1794
# mean       4.771873      NaN          NaN            NaN         NaN
# std        0.743204      NaN          NaN            NaN         NaN
# min        1.000000      NaN          NaN            NaN         NaN
# 25%        5.000000      NaN          NaN            NaN         NaN
# 50%        5.000000      NaN          NaN            NaN         NaN
# 75%        5.000000      NaN          NaN            NaN         NaN
# max        5.000000      NaN          NaN            NaN         NaN
#
#            reviewerName     reviewText     summary  unixReviewTime vote
# ...

# %% [markdown]
# The dataset contains 5264 reviews for 85 Beauty products from 991 reviewers

# %%
iphone_dataset=pd.read_json('data/apple_iphone_11_reviews.json', orient='records')
iphone_dataset.head()
# Out:
#                           product                    helpful_count  \
# 0  Apple iPhone XR (64GB) - Black  5,087 people found this helpful
# 1  Apple iPhone XR (64GB) - Black  2,822 people found this helpful
# 2  Apple iPhone XR (64GB) - Black  1,798 people found this helpful
# 3  Apple iPhone XR (64GB) - Black  1,366 people found this helpful
# 4  Apple iPhone XR (64GB) - Black    536 people found this helpful
#
#    total_comments                                                url  \
# 0              24  https://www.amazon.in/Apple-iPhone-XR-64GB-Bla...
# 1               6  https://www.amazon.in/Apple-iPhone-XR-64GB-Bla...
# 2               0  https://www.amazon.in/Apple-iPhone-XR-64GB-Bla...
# 3              14  https://www.amazon.in/Apple-iPhone-XR-64GB-Bla...
# 4               5  https://www.amazon.in/Apple-iPhone-XR-64GB-Bla...
#
#   review_country reviewed_at  \
# 0         India   2018-12-12
# 1         India   2018-11-17
# 2         India   2019-01-27
# ...

# %%
iphone_dataset.describe(include='all')
# Out:
#                                product helpful_count  total_comments  \
# count                             5010          5010     5010.000000
# unique                               1            49             NaN
# top     Apple iPhone XR (64GB) - Black             0             NaN
# freq                              5010          4270             NaN
# first                              NaN           NaN             NaN
# last                               NaN           NaN             NaN
# mean                               NaN           NaN        0.030938
# std                                NaN           NaN        0.589420
# min                                NaN           NaN        0.000000
# 25%                                NaN           NaN        0.000000
# 50%                                NaN           NaN        0.000000
# 75%                                NaN           NaN        0.000000
# max                                NaN           NaN       24.000000
#
# ...

# %% [markdown]
# In this dataset, we have 5010 reviews of Apple Iphone 11.
# A couple of comments :
# * The reviews are coming from a very large number of different customers
# * The structure is very similar to the beauty products dataset even though the source is not exactly the same
# * We can drop the product_company column, it does not bring any value

# %%
appliances_dataset=pd.read_json('data/ref/Appliances_5.json', lines=True)
appliances_dataset.head()
# Out:
#    overall  verified   reviewTime      reviewerID        asin  \
# 0        5      True  08 22, 2013  A34A1UP40713F8  B00009W3I4
# 1        5      True   02 8, 2016  A1AHW6I678O6F2  B00009W3PA
# 2        5      True   08 5, 2015   A8R48NKTGCJDQ  B00009W3PA
# 3        5      True  04 24, 2015   AR3OHHHW01A8E  B00009W3PA
# 4        5      True  03 21, 2015  A2CIEGHZ7L1WWR  B00009W3PA
#
#                        style     reviewerName  \
# 0  {'Style:': ' Dryer Vent'}    James. Backus
# 1       {'Size:': ' 6-Foot'}           kevin.
# 2       {'Size:': ' 6-Foot'}        CDBrannom
# 3       {'Size:': ' 6-Foot'}  Calvin E Reames
# 4       {'Size:': ' 6-Foot'}   albert j. kong
#
#                                           reviewText        summary  \
# 0  I like this as a vent as well as something tha...  Great product
# 1                                          good item     Five Stars
# 2                     Fit my new LG dryer perfectly.     Five Stars
# ...

# %% [markdown]
# Same source than beauty dataset

# %% [markdown]
# The beauty and the appliances datasets are subsets of a bigger dataset. For this main dataset, metada are provided to give more info about the products. Let's explore those metada

# %%
meta_data=pd.read_json('data/ref/meta_data.json', lines=True)
meta_data.head()
# Out:
#                                          description  \
# 0      [Brand new. Still in factory-sealed plastic.]
# 1  [If you're already a Photoshop user and want a...
# 2  [School To Home Notes: Note From the Teacher!\...
# 3  [Dooqi is a young brand specializing in high-e...
# 4                                [Cover for Nook HD]
#
#                                                title  \
# 0  Kelby Training DVD: The Adobe Photoshop CS5 7-...
# 1  Kelby Training DVD: Adobe Photoshop CS5 Power ...
# 2  TEACHERS FRIEND NOTE FROM THE TEACHER SCHOOL T...
# 3  [3-pack]Ipad Mini Screen Protector, Dooqi Scre...
# 4                            Hd+ Cheetah Cover- Nook
#
#                                                image            brand  \
# 0  [https://images-na.ssl-images-amazon.com/image...   Kelby Training
# 1  [https://images-na.ssl-images-amazon.com/image...   Kelby Training
# 2  [https://images-na.ssl-images-amazon.com/image...  TEACHERS FRIEND
# ...

# %%
meta_data[['asin','description','title','date','brand']].describe(include='all')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 1652, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
#               asin description                         title  \
# count        18772        5130                         18771
# unique       18521        4437                         18417
# top     B00006L39I          []  onepix Hard Case for MacBook
# freq             2         122                             7
# first          NaN         NaN                           NaN
# ...

# %% [markdown]
# There are a couple of duplicates in the dataset

# %% [markdown]
# For more info about the dataset, please check https://nijianmo.github.io/amazon/index.html
